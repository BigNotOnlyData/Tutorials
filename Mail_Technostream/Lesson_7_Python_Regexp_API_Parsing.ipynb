# %% [markdown]
# # 1. Регулярные выражения

# %% [markdown]
# [Статья TProger](https://tproger.ru/translations/regular-expression-python/)
#
# [Статья Хабр](https://habr.com/ru/post/349860/)

# %% [markdown]
# 📌 **Регулярное выражение** — это строка, задающая шаблон поиска подстрок в тексте.

# %%
import re

# %%
text = "Карта map  и объект bitmap - это разные вещи"
match = re.findall(r"\bmap\b", text)
print(match)
# Out:
# ['map']

# %% [markdown]
# >`\b` означает границу слова (с одной стороны буква, а с другой — нет)

# %% [markdown]
# 📌 Регулярные выражения имеют **спецсимволы** `.^$*+?{}[]\|()`, которые в регулярках являются **управляющими конструкциями**. Для написания их просто как символов требуется их **экранировать**, для чего нужно поставить перед ними знак `\`

# %%
text = "(еда), беда, победа"
match = re.findall(r"\(еда\)", text)
print(match)
# Out:
# ['(еда)']

# %% [markdown]
# ## 1.1. Символьный класс

# %% [markdown]
# `[..]` - Один из символов в скобках,

# %%
text = "Еда, беду, победа"
match = re.findall(r"[Ее]д[ау]", text)
print(match)
# Out:
# ['Еда', 'еду', 'еда']

# %% [markdown]
# `-` - дефис на первое место ставим, если его надо найти

# %%
text = "Еда, беду, -6 78 победа"
match = re.findall(r"[-0-9][0-9]", text)
print(match)
# Out:
# ['-6', '78']

# %% [markdown]
# `[^..]` - Любой символ, кроме перечисленных (инвертация)

# %%
text = "Еда, беду, -5 78 победа"
match = re.findall(r"[^0-9]", text)
print(match)
# Out:
# ['Е', 'д', 'а', ',', ' ', 'б', 'е', 'д', 'у', ',', ' ', '-', ' ', ' ', 'п', 'о', 'б', 'е', 'д', 'а']

# %% [markdown]
# ## 1.2. Квантификаторы (указание количества повторений)

# %% [markdown]
# *Общая запись:* `{m,n}` - где,
#
# `m` - минимальное число совпадений с выражением,
#
# `n` - максимальное число совпадений с выражением.

# %% [markdown]
# *Краткая форма записи:*
# + `{m}` - повторение выражения ровно `m` раз
# + `{m,}` - повторение от `m` и более раз
# + `{,n}` - повторение не более `n` раз

# %% [markdown]
# *Особые:*
# + `?` - аналог `{0,1}`
# + `*` - аналог `{0,}`
# + `+` - аналог `{1,}`

# %% [markdown]
# ### 1.2.1. Мажорный квантификатор (жадный)

# %% [markdown]
# 📌 По умолчанию квантификаторы жадные — захватывают максимально возможное число символов.

# %%
text = "Google,  Gooogle, Goooooogle"
match = re.findall(r"o{2,5}", text)
print(match)
# Out:
# ['oo', 'ooo', 'ooooo']

# %% [markdown]
# ### 1.2.2. Минорный квантификатор (ленивый)

# %% [markdown]
# 📌 Добавление `?` делает их ленивыми, они захватывают минимально возможное число символов

# %% [markdown]
# `{m,n}?`

# %%
text = "Google,  Gooogle, Goooooogle"
match = re.findall(r"o{2,5}?", text)
print(match)
# Out:
# ['oo', 'oo', 'oo', 'oo', 'oo']

# %% [markdown]
# ### Пример 1. Проверить правильность записи номера телефона

# %%
text = "87654561290"
match = re.findall(r"8\d{10}", text)
print(match)
# Out:
# ['87654561290']

# %% [markdown]
# ### Пример 2. Выделить тег

# %% [markdown]
# #### - мажорный

# %%
text = "<p>Картинка <img src='bq.jpg'> в тексте</p>"
match = re.findall(r"<img.*>", text)
print(match)
# Out:
# ["<img src='bq.jpg'> в тексте</p>"]

# %% [markdown]
# #### - ленивый

# %%
text = "<p>Картинка <img src='bq.jpg'> в тексте</p>"
match = re.findall(r"<img.*?>", text)
print(match)
# Out:
# ["<img src='bq.jpg'>"]

# %% [markdown]
# ## 1.3. Группировка

# %% [markdown]
# ### 1.3.1. Не сохраняющие скобки `(?:)`

# %% [markdown]
# 📌 **REGEXP** — шаблон, то **(?:REGEXP)** — эквивалентный ему шаблон. Разница только в том, что теперь к **(?:REGEXP)** можно применять квантификаторы, указывая, сколько именно раз должна повториться группа

# %%
text = " 01:23:45:67:89:ab"
match = re.findall(r"[0-9a-fA-F]{2}(?:[:-][0-9a-fA-F]{2}){5}", text)
print(match)
# Out:
# ['01:23:45:67:89:ab']

# %% [markdown]
# 📌 Также скобки `(?:...)` позволяют локализовать часть шаблона, внутри которого происходит перечисление.

# %% [markdown]
# > `|` - ИЛИ

# %%
text = "lat = 5, lon=7, a=9"
match = re.findall(r"(?:lat|lon)\s*=\s*\d+", text)
print(match)
# Out:
# ['lat = 5', 'lon=7']

# %% [markdown]
# ### 1.3.2. Сохраняющие скобки `()`

# %%
text = "lat = 5, lon=7, a=9"
match = re.findall(r"(lat|lon)\s*=\s*\d+", text)
print(match)
# Out:
# ['lat', 'lon']

# %%
text = "lat = 5, lon=7, a=9"
match = re.findall(r"(lat|lon)\s*=\s*(\d+)", text)
print(match)
# Out:
# [('lat', '5'), ('lon', '7')]

# %% [markdown]
# ### Пример. Сохранить путь к файлу

# %%
text = "<p>Картинка <img src='bq.jpg'> в тексте</p>"
match = re.findall(r"<img\s+[^>]*src=[\"'](.+?)[\"']", text)
print(match)
# Out:
# ['bq.jpg']

# %% [markdown]
# ### 1.3.3. Обращение к сохраняющей скобке

# %% [markdown]
# + Нумерованное. `\i` (i - натуральное число: 1, 2, 3...). Подставляет значение `i` сохраняющей скобки
# + Именнованное. `(?P<name>...)` -> `(?P=<name>)`

# %%
text = "<p>Картинка <img src='bq.jpg'> в тексте</p>"
match = re.findall(r"<img\s+[^>]*src=(?P<my_name>[\"'])(.+?)(?P=my_name)", text)
print(match)
# Out:
# [("'", 'bq.jpg')]

# %% [markdown]
# # 2. URL, HTTP запросы, API

# %% [markdown]
# ## 2.1. Структура URL

# %% [markdown]
# https://developer.mozilla.org/ru/docs/Learn/Understanding_URLs

# %%
from urllib.parse import urlparse, parse_qsl

url = "https://developer.mozilla.org/ru/search?key1=url&key2=API"
urlparse(url)
# Out:
# ParseResult(scheme='https', netloc='developer.mozilla.org', path='/ru/search', params='', query='key1=url&key2=API', fragment='')

# %%
dict(parse_qsl(urlparse(url).query))
# Out:
# {'key1': 'url', 'key2': 'API'}

# %% [markdown]
# ## 2.2. Типы HTTP запросов и ответов

# %% [markdown]
# [HTTP запросы](https://developer.mozilla.org/ru/docs/Web/HTTP/Methods)
#
# [Коды HTTP ответов](https://developer.mozilla.org/ru/docs/Web/HTTP/Status)

# %% [markdown]
# ## 2.3. API

# %% [markdown]
# 📌 __API__ (англ. Application Programming Interface — программный интерфейс приложения) — это набор способов и правил, по которым различные программы общаются между собой и обмениваются данными.
#
# 📌 С помощью интерфейса можно использовать возможности разных систем, не задумываясь о том, как они обрабатывают наши запросы и что у них «под капотом».
#
# 📌 Чаще всего __API__ аппилирует данными в формате __JSON__ (XML еще)

# %% [markdown]
# https://skillbox.ru/media/code/chto_takoe_api/

# %% [markdown]
# ## 2.4. Работа с JSON

# %% [markdown]
# Spotify API сайт -
# https://developer.spotify.com/console/get-track/?id=&market=

# %%
import requests
import json

# %%
with open('Spotify/spotify_api_token.key', mode='r') as f_key:
    spotify_api_token = f_key.readline().strip()
    
class SpotifyAPI:
    def __init__(self, token):
        self._token = token
        
    def get_track_info(self, track_id, market='US'):
        # посылаем get запрос, указываем аргуметнты и заголовки
        ret = requests.get('https://api.spotify.com/v1/tracks/{}'.format(track_id),
                          params={'market': market,},
                          headers={'Authorization': f"Bearer {self._token}"})
        return ret
    
spotify = SpotifyAPI(spotify_api_token)
r = spotify.get_track_info('4HcxwEqJIqtC5RE7oQtW32') 
r.status_code
# Out:
# 200

# %% [markdown]
# Получим ответ в __JSON__

# %%
r.headers
# Out:
# {'content-type': 'application/json; charset=utf-8', 'cache-control': 'public, max-age=73307', 'x-robots-tag': 'noindex, nofollow', 'access-control-allow-origin': '*', 'access-control-allow-headers': 'Accept, App-Platform, Authorization, Content-Type, Origin, Retry-After, Spotify-App-Version, X-Cloud-Trace-Context, client-token', 'access-control-allow-methods': 'GET, POST, OPTIONS, PUT, DELETE, PATCH', 'access-control-allow-credentials': 'true', 'access-control-max-age': '604800', 'content-encoding': 'gzip', 'strict-transport-security': 'max-age=31536000', 'x-content-type-options': 'nosniff', 'date': 'Tue, 17 Nov 2020 10:05:48 GMT', 'server': 'envoy', 'Via': 'HTTP/2 edgeproxy, 1.1 google', 'Alt-Svc': 'clear', 'Transfer-Encoding': 'chunked'}

# %% [markdown]
# Извлечение текстовой информации

# %%
print(r.text)
# Out:
# {
#   "album" : {
#     "album_type" : "compilation",
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/5EbRh58Y7BVaEeUY7slkl7"
#       },
#       "href" : "https://api.spotify.com/v1/artists/5EbRh58Y7BVaEeUY7slkl7",
#       "id" : "5EbRh58Y7BVaEeUY7slkl7",
#       "name" : "Demo",
#       "type" : "artist",
#       "uri" : "spotify:artist:5EbRh58Y7BVaEeUY7slkl7"
#     } ],
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/album/6b6BZZ5gYfNJqUEaPx9Vzv"
#     },
#     "href" : "https://api.spotify.com/v1/albums/6b6BZZ5gYfNJqUEaPx9Vzv",
#     "id" : "6b6BZZ5gYfNJqUEaPx9Vzv",
#     "images" : [ {
#       "height" : 640,
#       "url" : "https://i.scdn.co/image/ab67616d0000b2732d6cbf9ae6f4a8b556644775",
#       "width" : 640
#     }, {
#       "height" : 300,
#       "url" : "https://i.scdn.co/image/ab67616d00001e022d6cbf9ae6f4a8b556644775",
#       "width" : 300
#     }, {
#       "height" : 64,
#       "url" : "https://i.scdn.co/image/ab67616d000048512d6cbf9ae6f4a8b556644775",
#       "width" : 64
#     } ],
#     "name" : "The Best",
#     "release_date" : "1998-06-01",
#     "release_date_precision" : "day",
#     "total_tracks" : 20,
#     "type" : "album",
#     "uri" : "spotify:album:6b6BZZ5gYfNJqUEaPx9Vzv"
#   },
#   "artists" : [ {
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/artist/5EbRh58Y7BVaEeUY7slkl7"
#     },
#     "href" : "https://api.spotify.com/v1/artists/5EbRh58Y7BVaEeUY7slkl7",
#     "id" : "5EbRh58Y7BVaEeUY7slkl7",
#     "name" : "Demo",
#     "type" : "artist",
#     "uri" : "spotify:artist:5EbRh58Y7BVaEeUY7slkl7"
#   } ],
#   "available_markets" : [ ],
#   "disc_number" : 1,
#   "duration_ms" : 258896,
#   "explicit" : false,
#   "external_ids" : {
#     "isrc" : "QM6N21730015"
#   },
#   "external_urls" : {
#     "spotify" : "https://open.spotify.com/track/4HcxwEqJIqtC5RE7oQtW32"
#   },
#   "href" : "https://api.spotify.com/v1/tracks/4HcxwEqJIqtC5RE7oQtW32",
#   "id" : "4HcxwEqJIqtC5RE7oQtW32",
#   "is_local" : false,
#   "is_playable" : true,
#   "name" : "Солнышко",
#   "popularity" : 45,
#   "preview_url" : "https://p.scdn.co/mp3-preview/6bd1c869558d96087847d4d690220a4bd108b545?cid=774b29d4f13844c495f206cafdad9c86",
#   "track_number" : 1,
#   "type" : "track",
#   "uri" : "spotify:track:4HcxwEqJIqtC5RE7oQtW32"
# }

# %% [markdown]
# Сконвертируем __JSON__ в словарь

# %%
# 1 способ
answer = json.loads(r.text)
type(answer)
# Out:
# dict

# %%
# 2 способ
answer = r.json()
type(answer)
# Out:
# dict

# %%
answer_cut = {
    'artist': answer['artists'][0]['name'],
    'name': answer['name'],
    'duration': answer['duration_ms'] / 1000.0,
    'href': answer['href'],
    'id': answer['id'],
    'preview': answer['preview_url'],
}
answer_cut
# Out:
# {'artist': 'Demo',
#  'name': 'Солнышко',
#  'duration': 258.896,
#  'href': 'https://api.spotify.com/v1/tracks/4HcxwEqJIqtC5RE7oQtW32',
#  'id': '4HcxwEqJIqtC5RE7oQtW32',
#  'preview': 'https://p.scdn.co/mp3-preview/6bd1c869558d96087847d4d690220a4bd108b545?cid=774b29d4f13844c495f206cafdad9c86'}

# %% [markdown]
# Превью закодировано в бинарном формате. При помощи `content` извлечем информацию
#
# Сохраним превью отдельно

# %%
urlparse(answer_cut['preview']).path
# Out:
# '/mp3-preview/6bd1c869558d96087847d4d690220a4bd108b545'

# %%
filename = urlparse(answer_cut['preview']).path.split('/')[-1] + '.mp3'

with open(f'Spotify/{filename}', 'wb') as f:
    data = requests.get(answer_cut['preview']).content
    f.write(data)
    
print(filename)
# Out:
# 6bd1c869558d96087847d4d690220a4bd108b545.mp3

# %% [markdown]
# ### В Юпитере есть возможность проиграть мелодию

# %%
import IPython.display as ipd

ipd.Audio(f'Spotify/{filename}')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Сериализуем словарь в  __JSON__ строку

# %%
json.dumps(answer_cut, separators=(',', ':'))
# Out:
# '{"artist":"Demo","name":"\\u0421\\u043e\\u043b\\u043d\\u044b\\u0448\\u043a\\u043e","duration":258.896,"href":"https://api.spotify.com/v1/tracks/4HcxwEqJIqtC5RE7oQtW32","id":"4HcxwEqJIqtC5RE7oQtW32","preview":"https://p.scdn.co/mp3-preview/6bd1c869558d96087847d4d690220a4bd108b545?cid=774b29d4f13844c495f206cafdad9c86"}'

# %%
# pretty print для json
print(json.dumps(answer_cut, indent=4, sort_keys=True))
# Out:
# {
#     "artist": "Demo",
#     "duration": 258.896,
#     "href": "https://api.spotify.com/v1/tracks/4HcxwEqJIqtC5RE7oQtW32",
#     "id": "4HcxwEqJIqtC5RE7oQtW32",
#     "name": "\u0421\u043e\u043b\u043d\u044b\u0448\u043a\u043e",
#     "preview": "https://p.scdn.co/mp3-preview/6bd1c869558d96087847d4d690220a4bd108b545?cid=774b29d4f13844c495f206cafdad9c86"
# }

# %% [markdown]
# Сериализация в файл

# %%
with open('tmp/answer_cut.json', mode='w') as f_json:
    json.dump(answer_cut, f_json)

# %% [markdown]
# Распарсить содержимое файлика

# %%
with open('tmp/answer_cut.json', mode='r') as f_json:
    answer_cut = json.load(f_json)
    
print(type(answer_cut), answer_cut, sep='\n\n')
# Out:
# <class 'dict'>
#
# {'artist': 'Demo', 'name': 'Солнышко', 'duration': 258.896, 'href': 'https://api.spotify.com/v1/tracks/4HcxwEqJIqtC5RE7oQtW32', 'id': '4HcxwEqJIqtC5RE7oQtW32', 'preview': 'https://p.scdn.co/mp3-preview/6bd1c869558d96087847d4d690220a4bd108b545?cid=774b29d4f13844c495f206cafdad9c86'}

# %% [markdown]
# ## 2.5. А можноли как-то ускорить процесс обкачки?

# %% [markdown]
# ## Процессы и потоки

# %% [markdown]
# 📌 __Процессы__ использют своё конкретное адрессное пространство, в которое никто другой звлезть не может. В этои адрессном пространстве храняться данные процесса и исполняемый код.
#
# 📌 __Потоки (threads)__ - это сущности которые порождаются внутри процесса, соответственно у них общее адрессное пространство, потому что они работают внутри процесса

# %% [markdown]
# Встроенная библиотка  `asyncio`

# %%
# визуальное отображение процесса работы
from tqdm.notebook import tqdm

# %%
# %%time

n_post_first, n_post_final = 349000, 349200

r = [requests.get('https://habr.com/ru/post/{}/'.format(post_id))
    for post_id in tqdm(range(n_post_first, n_post_final, 2))]
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Wall time: 1min 17s

# %% [markdown]
# Параллелизация с помощью __ПОТОКОВ__

# %%
# библиотека для распаралелевания с помощью процессов и потоков
from multiprocessing.dummy import Pool as ThreadPool

# %%
# %%time

n_post_first, n_post_final = 349000, 349200

def get_habr_post(post_id):
    return requests.get('https://habr.com/ru/post/{}/'.format(post_id))
                        
with ThreadPool(10) as pool:
    r = pool.map(get_habr_post, range(n_post_first, n_post_final, 2))

pool.join()
# Out:
# Wall time: 4.54 s

# %% [markdown]
# Параллелизация с помощью __ПРОЦЕССОВ__
#
# Не хочет работать

# %%
from multiprocessing import Pool

# %%
# %%time

# n_post_first, n_post_final = 349000, 349200

# def get_habr_post(post_id):
#     return requests.get('https://habr.com/ru/post/{}/'.format(post_id))
                        
# with Pool(10) as pool:
#     r = pool.map(get_habr_post, range(n_post_first, n_post_final, 2))
    
# pool.join()

# %% [markdown]
# # 3. Парсинг HTML-страничек

# %% [markdown]
# Способы парсинга:
# + HTMLParser
# + lxml (древовидное, позволяет использовать XPath)
# + Beautiful Soup

# %%
from html.parser import HTMLParser

# %%
from lxml import etree, html as lhtml

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ## Пример. BeautifulSoup

# %% [markdown]
# https://www.crummy.com/software/BeautifulSoup/bs4/doc.ru/bs4ru.html#id28

# %%
film_url = 'https://www.kinopoisk.ru/film/322/'
film_html = requests.get(film_url).text

# %%
soup = BeautifulSoup(film_html, 'html.parser')

# %%
soup = BeautifulSoup(film_html, 'lxml')

# %% [markdown]
# ### Соберем основную информацию о фильме

# %%
film_info = {
    'title': soup.find('span', class_='styles_title__2l0HH').text,
    'title_original': soup.find('span', class_='styles_originalTitle__31aMS').text,
    'countries': [e.text for e in soup.find_all('div', class_='styles_valueDark__3dsUz styles_value__2F1uj')[3] if e.name == 'a'],
    'time': re.search('\d\d:\d\d', soup.find_all('div', class_='styles_valueDark__3dsUz styles_value__2F1uj')[-1].text).group(0),
    'rating': float(soup.select_one('a.film-rating-value').text),
    'description': soup.find('div', class_='styles_synopsisSection__OZA_d').text
}

film_info
# Out:
# {'title': 'Гарри Поттер и узник Азкабана',
#  'title_original': 'Harry Potter and the Prisoner of Azkaban',
#  'countries': ['Великобритания', 'США'],
#  'time': '02:22',
#  'rating': 8.146,
#  'description': 'В третьей части истории о юном волшебнике полюбившиеся всем герои — Гарри Поттер, Рон и Гермиона — возвращаются уже на третий курс школы чародейства и волшебства Хогвартс. На этот раз они должны раскрыть тайну узника, сбежавшего из зловещей тюрьмы Азкабан, чье пребывание на воле создает для Гарри смертельную опасность...'}

# %% [markdown]
# ### Извлечем таблицу

# %%
import pandas as pd

# %%
table = soup.select_one('div.styles_topLine__37rG1:nth-child(2) > div:nth-child(1) > div:nth-child(2)').contents
table
# Out:
# [<div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Год производства</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="a189db02"><a class="styles_linkDark__3aytH styles_link__1N3S2" href="/lists/navigator/2004/?quick_filters=films">2004</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Страна</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/lists/navigator/country-11/?quick_filters=films">Великобритания</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/lists/navigator/country-1/?quick_filters=films">США</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Жанр</div><div class="styles_valueDark__3dsUz styles_value__2F1uj styles_root__XK7Dx" data-tid="d61dc135"><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/lists/navigator/fantasy/?quick_filters=films">фэнтези</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/lists/navigator/adventure/?quick_filters=films">приключения</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/lists/navigator/family/?quick_filters=films">семейный</a></div><a class="styles_linkDark__3aytH styles_link__1N3S2 keywords" href="/film/322/keywords/">слова</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Слоган</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="849d1be2"><div class="styles_valueDark__3dsUz styles_value__2F1uj">«Всё изменится»</div></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Режиссер</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/50975/">Альфонсо Куарон</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Сценарий</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/10093/">Стивен Кловз</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/40777/">Дж.К. Роулинг</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Продюсер</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/24817/">Крис Коламбус</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/23449/">Дэвид Хейман</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/24862/">Марк Рэдклифф</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/cast/who_is/producer/">...</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Оператор</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/140954/">Майкл Серезин</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Композитор</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/225027/">Джон Уильямс</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Художник</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/1304399/">Стюарт Крэйг</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/1986594/">Эндрю Эклэнд-Сноу</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/1529416/">Алан Гилмор</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/cast/who_is/design/">...</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Монтаж</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/name/1988032/">Стивен Вайсберг</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Бюджет</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="a189db02"><a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/box/">$130 000 000</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Маркетинг</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="a189db02"><a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/box/">$50 000 000</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Сборы в США</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="a189db02"><a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/box/">$249 541 069</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Сборы в мире</div><div class="styles_valueDark__3dsUz styles_value__2F1uj styles_root__RwScy" data-tid="712ca0f8"><a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/box/">+ $546 093 000 = $795 634 069</a><a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/box/">сборы</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Зрители</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="56da96f5"><span class="styles_valueDark__3dsUz styles_value__2F1uj styles_item__3Eko1" data-tid="cf3e4d65"><img alt="США" class="styles_icon__XY2T2" src="https://st.kp.yandex.net/images/flags/flag-1.gif"/>40.2 млн </span>, <span class="styles_valueDark__3dsUz styles_value__2F1uj styles_item__3Eko1" data-tid="cf3e4d65"><img alt="Япония" class="styles_icon__XY2T2" src="https://st.kp.yandex.net/images/flags/flag-9.gif"/>11 млн </span>, <span class="styles_valueDark__3dsUz styles_value__2F1uj styles_item__3Eko1" data-tid="cf3e4d65"><img alt="Великобритания" class="styles_icon__XY2T2" src="https://st.kp.yandex.net/images/flags/flag-11.gif"/>10.3 млн </span>, <a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/dates/">...</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Сборы в России</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="a189db02"><a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/box/">$7 800 000</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Премьера в Росcии</div><div class="styles_root__ox7nn styles_valueDark__3dsUz styles_value__2F1uj" data-tid="c40ffdb5"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="2454e9be" href="/premiere/ru/2004/to/322/#322">3 июня 2004</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="2454e9be" href="/lists/m_act[company]/12/">«Каро-Премьер»</a><span class="styles_stickers__1bkFP"></span></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Премьера в мире</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="df943f2f"><a class="styles_linkDark__3aytH styles_link__1N3S2" data-tid="60f1c547" href="/film/322/dates/">23 мая 2004</a>, <a class="styles_linkDark__3aytH styles_link__1N3S2" href="/film/322/dates/">...</a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Релиз на DVD</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="849d1be2"><div class="styles_valueDark__3dsUz styles_value__2F1uj">16 сентября 2004, «Premier Digital»</div></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Релиз на Blu-ray</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="849d1be2"><div class="styles_valueDark__3dsUz styles_value__2F1uj">23 декабря 2008, «Юниверсал Пикчерс Рус»</div></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Возраст</div><div class="styles_valueDark__3dsUz styles_value__2F1uj styles_restrictionRow__33dYa" data-tid="4550ffc2"><a class="styles_restrictionLink__2FpSr"><span class="styles_rootHighContrast__2Q7Mf styles_rootHighContrastInLight__34VMm" data-tid="59555eb0">12+</span></a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Рейтинг MPAA</div><div class="styles_valueDark__3dsUz styles_value__2F1uj styles_restrictionRow__33dYa" data-tid="4550ffc2"><a class="styles_restrictionLink__2FpSr" href="/film/322/rn/PG/"><span class="styles_rootHighContrast__2Q7Mf styles_rootHighContrastInLight__34VMm" data-tid="59555eb0">PG</span><span class="styles_restrictionDescription__18aeV styles_valueDark__3dsUz styles_value__2F1uj">рекомендуется присутствие родителей</span></a></div></div>,
#  <div class="styles_rowDark__2qC4I styles_row__2ee6F" data-tid="a25321e6"><div class="styles_titleDark__3-gXe styles_title__a0_0F">Время</div><div class="styles_valueDark__3dsUz styles_value__2F1uj" data-tid="849d1be2"><div class="styles_valueDark__3dsUz styles_value__2F1uj">142 мин. / 02:22</div></div></div>]

# %%
data = {}
data['Название'] = soup.find('span', class_='styles_title__2l0HH').text

for row in table:
    col = row.select_one('div.styles_titleDark__3-gXe.styles_title__a0_0F').text
    data[col] = row.select_one('div.styles_valueDark__3dsUz.styles_value__2F1uj').text
    
data
# Out:
# {'Название': 'Гарри Поттер и узник Азкабана',
#  'Год производства': '2004',
#  'Страна': 'Великобритания, США',
#  'Жанр': 'фэнтези, приключения, семейныйслова',
#  'Слоган': '«Всё изменится»',
#  'Режиссер': 'Альфонсо Куарон',
#  'Сценарий': 'Стивен Кловз, Дж.К. Роулинг',
#  'Продюсер': 'Крис Коламбус, Дэвид Хейман, Марк Рэдклифф, ...',
#  'Оператор': 'Майкл Серезин',
#  'Композитор': 'Джон Уильямс',
#  'Художник': 'Стюарт Крэйг, Эндрю Эклэнд-Сноу, Алан Гилмор, ...',
#  'Монтаж': 'Стивен Вайсберг',
#  'Бюджет': '$130\xa0000\xa0000',
#  'Маркетинг': '$50\xa0000\xa0000',
#  'Сборы в США': '$249\xa0541\xa0069',
#  'Сборы в мире': '+ $546\xa0093\xa0000 = $795\xa0634\xa0069сборы',
#  'Зрители': '40.2 млн , 11 млн , 10.3 млн , ...',
#  'Сборы в России': '$7\xa0800\xa0000',
#  'Премьера в Росcии': '3 июня 2004,\xa0«Каро-Премьер»',
#  'Премьера в мире': '23 мая 2004, ...',
#  'Релиз на DVD': '16 сентября 2004, «Premier Digital»',
#  'Релиз на Blu-ray': '23 декабря 2008, «Юниверсал Пикчерс Рус»',
#  'Возраст': '12+',
#  'Рейтинг MPAA': 'PGрекомендуется присутствие родителей',
#  'Время': '142 мин. / 02:22'}

# %%
df = pd.DataFrame(data, index=[0])
df
# Out:
#                         Название Год производства               Страна  \
# 0  Гарри Поттер и узник Азкабана             2004  Великобритания, США
#
#                                   Жанр           Слоган         Режиссер  \
# 0  фэнтези, приключения, семейныйслова  «Всё изменится»  Альфонсо Куарон
#
#                       Сценарий  \
# 0  Стивен Кловз, Дж.К. Роулинг
#
#                                           Продюсер       Оператор  \
# 0  Крис Коламбус, Дэвид Хейман, Марк Рэдклифф, ...  Майкл Серезин
#
#      Композитор  ...                        Сборы в мире  \
# 0  Джон Уильямс  ...  + $546 093 000 = $795 634 069сборы
#
#                               Зрители Сборы в России  \
# 0  40.2 млн , 11 млн , 10.3 млн , ...     $7 800 000
#
#              Премьера в Росcии   Премьера в мире  \
# 0  3 июня 2004, «Каро-Премьер»  23 мая 2004, ...
#
#                           Релиз на DVD  \
# 0  16 сентября 2004, «Premier Digital»
#
#                            Релиз на Blu-ray Возраст  \
# 0  23 декабря 2008, «Юниверсал Пикчерс Рус»     12+
#
#                             Рейтинг MPAA             Время
# 0  PGрекомендуется присутствие родителей  142 мин. / 02:22
#
# [1 rows x 25 columns]

# %% [markdown]
# ### Пройдемся по спискам актеров

# %%
actors, actors_dublyazh = soup.select('ul.styles_list__I97eu')
print(actors, actors_dublyazh, sep='\n\n')
# Out:
# <ul class="styles_list__I97eu"><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/40778/" itemprop="actor">Дэниэл Рэдклифф</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/40780/" itemprop="actor">Руперт Гринт</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/40779/" itemprop="actor">Эмма Уотсон</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/24216/" itemprop="actor">Робби Колтрейн</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/26071/" itemprop="actor">Том Фелтон</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/6650/" itemprop="actor">Гари Олдман</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/14362/" itemprop="actor">Дэвид Тьюлис</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/21464/" itemprop="actor">Майкл Гэмбон</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/21466/" itemprop="actor">Ричард Гриффитс</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/36619/" itemprop="actor">Пэм Феррис</a></li></ul>
#
# <ul class="styles_list__I97eu"><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/1643974/" itemprop="actor">Николай Быстров</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/290512/" itemprop="actor">Ольга Сирина</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/1643982/" itemprop="actor">Лина Иванова</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/318217/" itemprop="actor">Рогволд Суховерко</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/4542546/" itemprop="actor">Александр Скрывля</a></li></ul>

# %%
[row.text for row in actors.children]
# Out:
# ['Дэниэл Рэдклифф',
#  'Руперт Гринт',
#  'Эмма Уотсон',
#  'Робби Колтрейн',
#  'Том Фелтон',
#  'Гари Олдман',
#  'Дэвид Тьюлис',
#  'Майкл Гэмбон',
#  'Ричард Гриффитс',
#  'Пэм Феррис']

# %%
[row.text for row in actors_dublyazh.children]
# Out:
# ['Николай Быстров',
#  'Ольга Сирина',
#  'Лина Иванова',
#  'Рогволд Суховерко',
#  'Александр Скрывля']

# %% [markdown]
# ### Обкачаем картинки

# %%
url = 'https://www.kinopoisk.ru/film/322/stills/'
film_photo_html = requests.get(url).content

# %%
print(url)
# Out:
# https://www.kinopoisk.ru/film/322/stills/

# %%
soup = BeautifulSoup(film_photo_html, 'html.parser')

# %%
images = list(map(lambda s: s.attrs['src'], soup.find('table', class_='fotos').find_all('img')[:10]))
images
# Out:
# ['https://st.kp.yandex.net/images/kadr/sm_2117012.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2117011.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2117010.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2117009.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2117008.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2117007.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2117006.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2117005.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2117004.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2116950.jpg']

# %%
for i in range(len(images)):
    filename = urlparse(images[i]).path.split('/')[-1]

    with open(f'Kinopoisk/{filename}', 'wb') as f:
        data = requests.get(images[i]).content
        f.write(data)

    print(filename)
# Out:
# sm_2117012.jpg
# sm_2117011.jpg
# sm_2117010.jpg
# sm_2117009.jpg
# sm_2117008.jpg
# sm_2117007.jpg
# sm_2117006.jpg
# sm_2117005.jpg
# sm_2117004.jpg
# sm_2116950.jpg

# %% [markdown]
# # 4. Заголовки

# %% [markdown]
# База шрифтов - https://www.dafont.com/

# %%
r = requests.get('https://www.dafont.com/')
len(r.text)
# Out:
# 0

# %% [markdown]
# В ответе ничего нет. __НЕОБХОДИМО__ передать заголовок - информацию о браузере

# %% [markdown]
# Библиотека для подстановки UserAgent: https://pypi.org/project/fake-useragent/
#
# Что у меня за браузер: https://developers.whatismybrowser.com/useragents/parse/?analyse-my-user-agent=yes#parse-useragent

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:82.0) Gecko/20100101 Firefox/82.0'}
r = requests.get('https://www.dafont.com/', headers=headers)
len(r.text)
# Out:
# 23019

# %% [markdown]
# # 5. Cookie

# %% [markdown]
# https://www.unisender.com/ru/support/about/glossary/chto-takoe-cookies/

# %% [markdown]
# 📌 **Cookie (куки)**- это небольшие текстовые файлы, в которые браузер записывает данные с посещенных вами сайтов. Файлы **cookie** позваляют сайтам "запоминать" своих посетителей, например, чтобы каждый раз не переспрашивать их логин и пароль.

# %%
r = requests.get('https://sphere.mail.ru/people/', params={'q': 'BD-11'})
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(film_photo_html, 'html.parser')

table = soup.find('div', class_='people-list')
table is not None
# Out:
# False

# %%
print(r.url)
# Out:
# https://sphere.mail.ru/pages/index/?next=/people/%3Fq%3DBD-11#auth

# %%
r = r.history[0]
r.status_code, r.is_redirect
# Out:
# (302, True)

# %%
print(r.url)
# Out:
# https://sphere.mail.ru/people/?q=BD-11

# %% [markdown]
# Если бы были куки, то можно было зайти на сайт без явной авторизации

# %%
# r = requests.get('https://sphere.mail.ru/people/', params={'q': 'BD-11'}, cookies=cookies)

# %% [markdown]
# # 6. Proxy

# %% [markdown]
# 📌 **Proxy** - сторонний сервер, через который передаётся трафик

# %%
def browser_status_from_yandex(**params):
    r = requests.get('https://yandex.ru/internet/', **params)
    soup = BeautifulSoup(r.content, 'html.parser')
    
    params = {}
    for e in soup.find('ul', class_='general-info').find_all('li'):
        key = e.find('h3').text
        val = e.find('div', {'class': None})
        val = val.text if val else '-'
        params[key] = val
    return params

# %%
browser_status_from_yandex()
# Out:
# {'IPv4-адрес': '95.26.50.205',
#  'IPv6-адрес': '–',
#  'Браузер': 'Неизвестный браузер',
#  'Разрешение экрана': '–',
#  'Регион': '-',
#  'JavaScript отключен': 'В вашем браузере отсутствует или выключена поддержка JavaScript.'}

# %% [markdown]
# https://spys.one/proxys/DE/

# %%
proxies = {'htpps': '179.185.35.229:3128'}
browser_status_from_yandex(proxies=proxies)
# Out:
# {'IPv4-адрес': '95.26.50.205',
#  'IPv6-адрес': '–',
#  'Браузер': 'Неизвестный браузер',
#  'Разрешение экрана': '–',
#  'Регион': '-',
#  'JavaScript отключен': 'В вашем браузере отсутствует или выключена поддержка JavaScript.'}

# %% [markdown]
# Почему-то IP адрес не поменялся

# %%
browser_status_from_yandex(proxies=proxies, headers=headers)
# Out:
# {'IPv4-адрес': '95.26.50.205',
#  'IPv6-адрес': '–',
#  'Браузер': 'Firefox 82.0 (Gecko 82.0)',
#  'Разрешение экрана': '–',
#  'Регион': '-',
#  'JavaScript отключен': 'В вашем браузере отсутствует или выключена поддержка JavaScript.'}

# %%
# изменили браузер на хром
headers = {'User-Agent': 'User-Agent: Mozilla/5.0 (Linux; Android 9; Pixel 2 XL Build/PPP3.180510.008) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Mobile Safari/537.36'}
browser_status_from_yandex(proxies=proxies, headers=headers)
# Out:
# {'IPv4-адрес': '95.26.50.205',
#  'IPv6-адрес': '–',
#  'Браузер': 'Google Chrome Mobile 67.0.3396 (WebKit 537.36)',
#  'Разрешение экрана': '–',
#  'Регион': '-',
#  'JavaScript отключен': 'В вашем браузере отсутствует или выключена поддержка JavaScript.'}

# %% [markdown]
# # 7. Selenium

# %% [markdown]
# 📌 Создавалась для Автоматизации тестирования вебсайтов
#
# Мы будем использовать как средство управления браузера

# %%
url_format = 'https://www.banki.ru/banks/map/{city}/#/!b1:{bank_ids}!s3:{bank_types}!s4:list!m4:1!p1:{page}'

# %%
url_params = {
    'city': 'drugie/lyubertssyi',
    'bank_ids': 'all',
    'bank_types': 'all',
    'page': 1,
}

# %%
url_current = url_format.format(**url_params)
print(url_current)
# Out:
# https://www.banki.ru/banks/map/drugie/lyubertssyi/#/!b1:all!s3:all!s4:list!m4:1!p1:1

# %%
r = requests.get(url_current).content

# %%
soup = BeautifulSoup(r, 'html.parser')
print(soup.find('div', {'class': 'branches__list'}))
# Out:
# <div class="branches__list branches__list--hidden" id="branches__list"></div>

# %% [markdown]
# Получили пустой тег, хотя он на самом деле не пустой. Все дело в **JavaScript**. Когда браузер загружает страницу он выполняет скрипт и появляется информация.
#
# Нам поможет **Selenium**

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\programs\anaconda\anaconda3\lib\site-packages (from selenium) (1.25.8)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from selenium import webdriver

import html
from time import sleep

# %%
with webdriver.Firefox() as driver:
    driver.get("https://mail.ru/")
    sleep(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Programs\Anaconda\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# C:\Programs\Anaconda\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# C:\Programs\Anaconda\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1206                                          os.fspath(cwd) if cwd is not None else None,
# -> 1207                                          startupinfo)
#    1208             finally:
#
# FileNotFoundError: [WinError 2] Не удается найти указанный файл
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-26-502888f76d66> in <module>
# ----> 1 with webdriver.Firefox() as driver:
#       2     driver.get("https://mail.ru/")
#       3     sleep(3)
#
# C:\Programs\Anaconda\anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     162                 service_args=service_args,
#     163                 log_path=service_log_path)
# --> 164             self.service.start()
#     165
#     166             capabilities.update(options.to_capabilities())
#
# C:\Programs\Anaconda\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'geckodriver' executable needs to be in PATH.

# %% [markdown]
# selenium может нажимать кнопки, прокручивать страницы и т.д. в браузере...
